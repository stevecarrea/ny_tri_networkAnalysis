# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
allFacilities = pd.read_csv("output/describeNetwork.csv", dtype={'primary_naics': object})
naics = pd.read_csv("data/naics.csv", dtype={'2012 NAICS US Code': object})

# %%
# Count total facilities per community
allFacilities['Community'].hist(bins=[0,1,2,3,4,5], figsize=(12,12), ylabelsize=20, xlabelsize=20)

# %%
allFacilities['Degrees'].hist(figsize=(12,12), ylabelsize=20, xlabelsize=20)

# %%
naics = naics.drop(naics.columns[[0,3,4]], axis=1)
naics.columns = ["naics", "industry"]

# %%
naics[naics['naics'].str.len()==6]
# Out:
#        naics                                           industry
# 5     111110                                    Soybean Farming
# 7     111120                  Oilseed (except Soybean) Farming
# 9     111130                          Dry Pea and Bean Farming
# 11    111140                                      Wheat Farming
# 13    111150                                      Corn Farming
# 15    111160                                       Rice Farming
# 17    111191             Oilseed and Grain Combination Farming
# 18    111199                           All Other Grain Farming
# 21    111211                                    Potato Farming
# 22    111219  Other Vegetable (except Potato) and Melon Farm...
# 25    111310                                      Orange Groves
# 27    111320                     Citrus (except Orange) Groves
# 29    111331                                    Apple Orchards
# 30    111332                                   Grape Vineyards
# 31    111333                                Strawberry Farming
# 32    111334                 Berry (except Strawberry) Farming
# 33    111335                                  Tree Nut Farming
# 34    111336            Fruit and Tree Nut Combination Farming
# 35    111339                     Other Noncitrus Fruit Farming
# 38    111411                               Mushroom Production
# 39    111419                Other Food Crops Grown Under Cover
# 41    111421                       Nursery and Tree Production
# 42    111422                           Floriculture Production
# 45    111910                                    Tobacco Farming
# 47    111920                                     Cotton Farming
# 49    111930                                  Sugarcane Farming
# 51    111940                                       Hay Farming
# 53    111991                                Sugar Beet Farming
# 54    111992                                    Peanut Farming
# 55    111998              All Other Miscellaneous Crop Farming
# ...      ...                                                ...
# 2134  814110                                 Private Households
# 2139  921110                                 Executive Offices
# 2141  921120                                Legislative Bodies
# 2143  921130                         Public Finance Activities
# 2145  921140       Executive and Legislative Offices, Combined
# 2147  921150  American Indian and Alaska Native Tribal Gover...
# 2149  921190                  Other General Government Support
# 2153  922110                                            Courts
# 2155  922120                                 Police Protection
# 2157  922130                     Legal Counsel and Prosecution
# 2159  922140                         Correctional Institutions
# 2161  922150              Parole Offices and Probation Offices
# 2163  922160                                   Fire Protection
# 2165  922190  Other Justice, Public Order, and Safety Activi...
# 2169  923110              Administration of Education Programs
# 2171  923120          Administration of Public Health Programs
# 2173  923130  Administration of Human Resource Programs (exc...
# 2175  923140               Administration of Veterans' Affairs
# 2179  924110  Administration of Air and Water Resource and S...
# 2181  924120           Administration of Conservation Programs
# 2185  925110                Administration of Housing Programs
# 2187  925120  Administration of Urban Planning and Community...
# 2191  926110       Administration of General Economic Programs
# 2193  926120  Regulation and Administration of Transportatio...
# 2195  926130  Regulation and Administration of Communication...
# 2197  926140  Regulation of Agricultural Marketing and Commo...
# 2199  926150  Regulation, Licensing, and Inspection of Misce...
# 2203  927110                     Space Research and Technology
# 2207  928110                                 National Security
# 2209  928120                             International Affairs
#
# [1065 rows x 2 columns]

# %%
allFacilities = allFacilities.merge(naics, left_on=["primary_naics"], right_on="naics", how="left")
allFacilities = allFacilities.drop("naics", axis=1)

# %%
allFacilities.to_csv('output/facilitiesWithNaics.csv')

# %%
# this makes dict of DFs, which are written to indivual .csv files
communities = defaultdict(dict)

for i in allFacilities['Community'].unique():
    commData = allFacilities[allFacilities['Community']==i]
    communities[i]['ungroupedData'] = commData
    industries = commData.groupby(['primary_naics', 'industry']).size().order(ascending=False)
    industries = industries.reset_index()
    industries = industries.rename(columns = {0:'countPerComm'})
    industries['percentPerComm'] = (industries['countPerComm'] / len(commData))*100
    communities[i]['groupedData'] = industries
# Out:
# /Users/afair/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: FutureWarning: order is deprecated, use sort_values(...)

# %%
for i in communities:
    communities[i]['groupedData'].to_csv('output/community{}.csv'.format(i))

# %%
# this does pretty much same as above, except writes to one master DF and .csv rather than separate files
commDict = {}

for i in allFacilities['Community'].unique():
    commData = allFacilities[allFacilities['Community']==i]
    industries = commData.groupby(['primary_naics', 'industry']).size().order(ascending=False)
    industries = industries.reset_index()
    industries = industries.rename(columns = {0:'countPerComm'})
    industries['percentPerComm'] = (industries['countPerComm'] / len(commData))*100
    industries['community'] = i
    commDict[i] = industries
# Out:
# /Users/afair/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:6: FutureWarning: order is deprecated, use sort_values(...)

# %%
commDF = pd.concat([commDict[f] for f in commDict])
cols = commDF.columns.tolist()
cols = cols[-1:] + cols[:-1]
commDF = commDF[cols]
commDF = commDF.reset_index(drop=True)

# %%
commDF.to_csv('output/allCommunities.csv')

# %%
# print top n industries for each community
n = 3
commDF_topNAICS = commDF.groupby('community').head(n)
commDF_topNAICS.to_csv('output/allCommunities_topNAICS.csv')

# %%
# print bottom n industries for each community
n = 3
commDF_bottomNAICS.groupby('community').tail(n)
commDF_bottomNAICS.to_csv('output/allCommunities_bottomNAICS.csv')
# Out:
#      community primary_naics  \
# 72           0        331410
# 73           0        327993
# 74           0        212399
# 105          1        335999
# 106          1        337215
# 107          1        326220
# 109          2        336112
# 110          2        326130
# 111          2        325991
# 124          3        322299
# 125          3        311513
# 126          3        311511
# 188          4        424710
# 189          4        332410
# 190          4        311942
# 192          5        332215
# 193          5        332119
# 194          5        326199
#
#                                               industry  countPerComm  \
# 72   Nonferrous Metal (except Aluminum) Smelting an...             1
# 73                         Mineral Wool Manufacturing              1
# 74               All Other Nonmetallic Mineral Mining              1
# 105  All Other Miscellaneous Electrical Equipment a...             1
# 106  Showcase, Partition, Shelving, and Locker Manu...             1
# 107  Rubber and Plastics Hoses and Belting Manufact...             1
# 109     Light Truck and Utility Vehicle Manufacturing              1
# 110  Laminated Plastics Plate, Sheet (except Packag...             1
# 111            Custom Compounding of Purchased Resins              1
# 124   All Other Converted Paper Product Manufacturing              1
# 125                              Cheese Manufacturing              1
# 126                          Fluid Milk Manufacturing              1
# 188             Petroleum Bulk Stations and Terminals              1
# 189      Power Boiler and Heat Exchanger Manufacturing             1
# 190                   Spice and Extract Manufacturing              1
# 192  Metal Kitchen Cookware, Utensil, Cutlery, and ...             1
# 193  Metal Crown, Closure, and Other Metal Stamping...             1
# 194          All Other Plastics Product Manufacturing              1
#
#      percentPerComm
# 72         0.671141
# 73         0.671141
# 74         0.671141
# 105        1.250000
# 106        1.250000
# 107        1.250000
# 109       11.111111
# 110       11.111111
# 111       11.111111
# 124        2.083333
# 125        2.083333
# 126        2.083333
# 188        1.030928
# 189        1.030928
# 190        1.030928
# 192       25.000000
# 193       25.000000
# 194       25.000000

# %%
# print all industries for each community
allCommunities = commDF.groupby('community').apply(lambda x: x)
allCommunities[allCommunities['community'] == 1]  # Toggle through the communities
# Out:
#      community primary_naics  \
# 75           1        424710
# 76           1        325211
# 77           1        493190
# 78           1        221112
# 79           1        326150
# 80           1        325412
# 81           1        325510
# 82           1        311514
# 83           1        313320
# 84           1        322220
# 85           1        325193
# 86           1        325199
# 87           1        424690
# 88           1        326113
# 89           1        321999
# 90           1        324199
# 91           1        325320
# 92           1        325910
# 93           1        339940
# 94           1        339112
# 95           1        326199
# 96           1        339999
# 97           1        327992
# 98           1        327999
# 99           1        331314
# 100          1        332431
# 101          1        332999
# 102          1        333912
# 103          1        334510
# 104          1        334517
# 105          1        335999
# 106          1        337215
# 107          1        326220
#
#                                               industry  countPerComm  \
# 75              Petroleum Bulk Stations and Terminals             26
# 76          Plastics Material and Resin Manufacturing              5
# 77                       Other Warehousing and Storage             4
# 78              Fossil Fuel Electric Power Generation              4
# 79   Urethane and Other Foam Product (except Polyst...             3
# 80           Pharmaceutical Preparation Manufacturing              3
# 81                     Paint and Coating Manufacturing             3
# 82   Dry, Condensed, and Evaporated Dairy Product M...             2
# 83                                Fabric Coating Mills             2
# 84   Paper Bag and Coated and Treated Paper Manufac...             2
# 85                        Ethyl Alcohol Manufacturing              2
# 86     All Other Basic Organic Chemical Manufacturing              2
# 87   Other Chemical and Allied Products Merchant Wh...             2
# 88   Unlaminated Plastics Film and Sheet (except Pa...             1
# 89   All Other Miscellaneous Wood Product Manufactu...             1
# 90   All Other Petroleum and Coal Products Manufact...             1
# 91   Pesticide and Other Agricultural Chemical Manu...             1
# 92                          Printing Ink Manufacturing             1
# 93        Office Supplies (except Paper) Manufacturing             1
# 94      Surgical and Medical Instrument Manufacturing              1
# 95           All Other Plastics Product Manufacturing              1
# 96              All Other Miscellaneous Manufacturing              1
# 97   Ground or Treated Mineral and Earth Manufactur...             1
# 98   All Other Miscellaneous Nonmetallic Mineral Pr...             1
# 99        Secondary Smelting and Alloying of Aluminum              1
# 100                           Metal Can Manufacturing              1
# 101  All Other Miscellaneous Fabricated Metal Produ...             1
# 102              Air and Gas Compressor Manufacturing              1
# 103  Electromedical and Electrotherapeutic Apparatu...             1
# 104               Irradiation Apparatus Manufacturing              1
# 105  All Other Miscellaneous Electrical Equipment a...             1
# 106  Showcase, Partition, Shelving, and Locker Manu...             1
# 107  Rubber and Plastics Hoses and Belting Manufact...             1
#
#      percentPerComm
# 75            32.50
# 76             6.25
# 77             5.00
# 78             5.00
# 79             3.75
# 80             3.75
# 81             3.75
# 82             2.50
# 83             2.50
# 84             2.50
# 85             2.50
# 86             2.50
# 87             2.50
# 88             1.25
# 89             1.25
# 90             1.25
# 91             1.25
# 92             1.25
# 93             1.25
# 94             1.25
# 95             1.25
# 96             1.25
# 97             1.25
# 98             1.25
# 99             1.25
# 100            1.25
# 101            1.25
# 102            1.25
# 103            1.25
# 104            1.25
# 105            1.25
# 106            1.25
# 107            1.25

# %%
# # change community! (0-5)
# community = 0

# colsToDrop = ['Unnamed: 0','primary_naics', 'Betweeness', 'Closeness', 'Eigenvector']
# community_table = allFacilities[allFacilities['Community']==community].drop(colsToDrop, axis=1)
# community_table.columns = map(str.lower, community_table.columns)
# community_table
